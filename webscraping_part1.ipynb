# %%
import shutil
import tempfile
import urllib.request

with urllib.request.urlopen('http://python.org/') as response:
    with tempfile.NamedTemporaryFile(delete=False) as tmp_file:
        shutil.copyfileobj(response, tmp_file)

with open(tmp_file.name) as html:
    pass
r = requests.get('https://www.globaltimes.cn/content/1199107.shtml').text
headline = re.search('<title>(.*?)<', r).group(1)
author = re.search('<div class="span8 text-left">(.*?):', r).group(1)
content = re.search('<div class="span12 row-content">(.*?)<div class="pull-left">', r, re.S).group(1)
##____________________________________________________________________________________________________
import re
import requests

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36'}
r= requests.get('http://usa.people.com.cn/', headers = headers).text

home_page = re.search('class="pd_nav.?>(.?)</div>', r, re.S).group(1)

for x in home_page.split('href=')[1:]:
    cat = re.search('"(.*?)"', x, re.S).group(1)
    cat =  'http://usa.people.com.cn/'+cat
    print(cat)
    
#__________________________________________________________________________________________________________
import re
import requests

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36'}
r= requests.get('https://english.cdn.zeenews.com/sites/default/files/2020/09/07/884175-pjimage-2.jpg', headers = headers).content

with open('xyz.png','wb') as F:
    F.write(r)
    
#_______________________________________________________________________________________________________________

# %%
from urllib.request import urlopen 
from urllib.error import HTTPError
from urllib.error import URLError
try:
    html = urlopen("https://abcxyz.com")
except HTTPError as e:
    print("Http Error")
except URLError as e:
    print("url Error")
else:
    print(html.read())
    
try:
    html=urlopen("https://www.fundoodata.com/learning-center/top-10-public-limited-companies-india/")
except HTTPError as e:
    print("HttpError")
except URLError as e:
    print("Url Error")
else:
    print("Html Details")
    print(html.read())
# Out:
# url Error
# Html Details
# ...

# %%
import requests
response = requests.get("https://en.wikipedia.org/robots.txt")
test = response.text
print("robots.txt for http://www.wikipedia.org/")
print("===================================================")
print(test)
# Out:
# robots.txt for http://www.wikipedia.org/
# ...
# ﻿# robots.txt for http://www.wikipedia.org/ and friends
# #
# # Please note: There are a lot of pages on this site, and there are
# # some misbehaved spiders out there that go _way_ too fast. If you're
# # irresponsible, your access to the site may be blocked.
# #
#
# # Observed spamming large amounts of https://en.wikipedia.org/?curid=NNNNNN
# # and ignoring 429 ratelimit responses, claims to respect robots:
# # http://mj12bot.com/
# User-agent: MJ12bot
# Disallow: /
#
# # advertising-related bots:
# User-agent: Mediapartners-Google*
# Disallow: /
#
# # Wikipedia work bots:
# User-agent: IsraBot
# Disallow:
#
# User-agent: Orthogaffe
# Disallow:
#
# # Crawlers that are kind enough to obey, but which we'd rather not have
# # unless they're feeding search engines.
# User-agent: UbiCrawler
# Disallow: /
#
# User-agent: DOC
# Disallow: /
#
# User-agent: Zao
# Disallow: /
#
# ...

# %%
import requests
geo_url = 'http://maps.googleapis.com/maps/api/geocode/json'
my_address = {'address': '21 Ramkrishana Road, Burdwan, East Burdwan, West Bengal, India', 
             'language': 'en'}
response = requests.get(geo_url, params = my_address)
results = response.json()['results']
my_geo = results[0]['geometry']['location']
print("Longitude:",my_geo['lng'],"\n","Latitude:",my_geo['lat'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-305322081b02> in <module>
#       5 response = requests.get(geo_url, params = my_address)
#       6 results = response.json()['results']
# ----> 7 my_geo = results[0]['geometry']['location']
#       8 print("Longitude:",my_geo['lng'],"\n","Latitude:",my_geo['lat'])
#
# IndexError: list index out of range

# %%
from urllib.request import urlopen 
import requests
import re
import pandas as pd
from openpyxl import load_workbook
import os


quotes_list = []
countofAllpage = []
val = ['&#8230','&#8217','&#8220','&#8221']
#html=urlopen("https://www.fundoodata.com/learning-center/top-10-public-limited-companies-india/")
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36'}
for x in range(1,7):
    response=requests.get(f"https://www.coolnsmart.com/regret_quotes/page/{x}/",headers=headers).text
    response = response.replace('&#8230', '')
    response = response.replace('&#8217', '')
    response = response.replace('&#8220', '')
    response = response.replace('&#8221', '')
    response = response.replace(';', '')
    content=re.findall('<div\s*class="rtup">.*?<p>(.*?)<', response, re.S)
    
    quotes_list.append(content)
    countofAllpage.append(len(content))
    quotes_list=quotes_list+content
print(quotes_list)
print(countofAllpage)
df = pd.DataFrame(quotes_list)
#print(df)
#os.chdir(r"C:\Aishwarya\PythonPractice")
writer = pd.ExcelWriter('Quotes.xlsx') 
df.to_excel(writer, sheet_name = 's1')
writer.save()
writer.close()
# Out:
# [['We spend so much time being afraid of failure, afraid of rejection. But regret is the thing we should fear most.', 'I don’t regret anything. I did everything absolutely correctly.', 'Sure, you wish you did some things differently. But there is no sense in becoming burdened with regret over things you have no power to change.', 'It’s nice to look back on your life and see things as lessons, and not regrets.', 'Ask God for forgiveness, and leave your regrets in the past.', 'Im very sorry if I offended anybody. Id like to put it in the past now. Whats done is done. I regret it.', 'When you get to be 50, you will know that the bulk of your regrets are from not having done what you wished to do.', 'No amount of regretting can change the past, and no amount of worrying can change the future.', 'The regret of my life is that I have not said ‘I love you’ often enough.', 'Nothing can kill your soul more than the feeling of regret.', 'Looking back in retrospect and regretting your past, you
# ...
